# %%
! git clone https://github.com/Potladurthy-Sai-Praneeth/Parllel-Speculative-Decoding.git

# %%
! sh /kaggle/working/Parllel-Speculative-Decoding/install.sh

# %% [markdown]
# # Coding  - Humaneval - n=3

# %%
# Codegen
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_humaneval.py -n 3 -e output_n_3_codegen_humaneval --drafts codegen-350m-multi codegen-350m-mono codegen-350m-nl --target codegen-2b --data_path /kaggle/working/Parllel-Speculative-Decoding/data/humaneval.jsonl

# %%
# Qwen
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_humaneval.py -n 3  -e output_n_3_qwen_humaneval --drafts qwen-0.5b-instruct qwen-0.5b-coder qwen-0.5b --target qwen-1.5b --data_path /kaggle/working/Parllel-Speculative-Decoding/data/humaneval.jsonl

# %% [markdown]
# # Coding - MBPP - n=3

# %%
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_mbpp.py -n 3  -e output_n_3_qwen_mbpp --drafts qwen-0.5b-instruct qwen-0.5b-coder qwen-0.5b --target qwen-1.5b --data_path /kaggle/working/Parllel-Speculative-Decoding/data/mbpp.jsonl

# %%
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_mbpp.py -n 3  -e output_n_3_codegen_mbpp --drafts codegen-350m-multi codegen-350m-mono codegen-350m-nl --target codegen-2b --data_path /kaggle/working/Parllel-Speculative-Decoding/data/mbpp.jsonl

# %%
# Math n=3

# %%
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_gsm8k.py -n 3  -e output_n_3_gsm8_qwen --drafts qwen-0.5b-instruct qwen-0.5b-coder qwen-0.5b --target qwen-1.5b --data_path /kaggle/working/Parllel-Speculative-Decoding/data/gsm8k.jsonl

# %% [markdown]
# # Coding - Humaneval -  n=2

# %%
# Codegen
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_humaneval.py -n 2 -e output_n_2_phi_humaneval --drafts phi-1 phi-1.5 --target phi-2 --data_path /kaggle/working/Parllel-Speculative-Decoding/data/humaneval.jsonl

# %%
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_humaneval.py -n 2  -e output_n_2_smo_humaneval --drafts smo-360m-instruct smo-360m --target smo-1.7b --data_path /kaggle/working/Parllel-Speculative-Decoding/data/humaneval.jsonl

# %% [markdown]
# # Coding - MBPP -  n=2

# %%
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_mbpp.py -n 2  -e output_n_2_phi_mbpp --drafts phi-1 phi-1.5 --target phi-2 --data_path /kaggle/working/Parllel-Speculative-Decoding/data/mbpp.jsonl

# %%
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_mbpp.py -n 2  -e output_n_2_smo_mbpp smo-360m-instruct smo-360m --target smo-1.7b --data_path /kaggle/working/Parllel-Speculative-Decoding/data/mbpp.jsonl

# %% [markdown]
# # Math -n=3

# %%
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_math.py -n 3  -e output_n_3_math_qwen --drafts qwen-0.5b-instruct qwen-0.5b-coder qwen-0.5b --target qwen-1.5b --data_path /kaggle/working/Parllel-Speculative-Decoding/data/math500.jsonl

# %%
# Math - n=2 - GSM8

# %%
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_gsm8k.py -n 2  -e output_n_2_smo_gsm8 smo-360m-instruct smo-360m --target smo-1.7b --data_path /kaggle/working/Parllel-Speculative-Decoding/data/gsm8k.jsonl

# %%
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_gsm8k.py -n 2  -e output_n_2_phi_gsm8 --drafts phi-1 phi-1.5 --target phi-2 --data_path /kaggle/working/Parllel-Speculative-Decoding/data/gsm8k.jsonl

# %%
# Math - n=2 - Math500

# %%
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_math.py -n 2  -e output_n_2_smo_math smo-360m-instruct smo-360m --target smo-1.7b --data_path /kaggle/working/Parllel-Speculative-Decoding/data/math500.jsonl

# %%
! set CUDA_VISIBLE_DEVICES=0,1
! set CUDA_LAUNCH_BLOCKING=1
! accelerate launch /kaggle/working/Parllel-Speculative-Decoding/benchmark/eval_math.py -n 2  -e output_n_2_phi_math --drafts phi-1 phi-1.5 --target phi-2 --data_path /kaggle/working/Parllel-Speculative-Decoding/data/math500.jsonl
